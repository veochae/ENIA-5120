# %%
import pandas as pd

# %%
pd.read_csv("/Users/veochae/Desktop/ENIA-5120/data/laser_league_events.csv").columns
# Out:
# Index(['event_id', 'squad_code', 'program_name', 'mentor', 'training_hours',
#        'bonus_tokens', 'event_date', 'event_location', 'satisfaction_rating'],
#       dtype='object')

# %%
pd.read_csv("/Users/veochae/Desktop/ENIA-5120/data/laser_league_players.csv").columns
